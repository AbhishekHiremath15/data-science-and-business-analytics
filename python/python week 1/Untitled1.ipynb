# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('books.csv')

# %%
data.shape
# Out:
# (5000, 10)

# %%
datatype(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 datatype(df)
#
# NameError: name 'datatype' is not defined

# %%
books_data = pd.read_csv[{"title": "average_rating"}]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 books_data = pd.read_csv[{"title": "average_rating"}]
#
# TypeError: 'function' object is not subscriptable

# %%
print(books_data)
# Out:
# [{'title': 'average_rating'}]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               5000 non-null   object
#  1   author              5000 non-null   object
#  2   average_rating      5000 non-null   float64
#  3   isbn13              5000 non-null   int64
#  4   language_code       4923 non-null   object
#  5   num_pages           4967 non-null   float64
#  6   ratings_count       5000 non-null   int64
#  7   text_reviews_count  5000 non-null   int64
#  8   publisher           5000 non-null   object
#  9   year                5000 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 390.8+ KB

# %%
df['average_rating'] = df.iloc[:,1:].mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['average_rating'] = df.iloc[:,1:].mean(axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11335, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11327 @doc(make_doc("mean", ndim=2))
#   11328 def mean(
#   11329     self,
#    (...)
#   11333     **kwargs,
#   11334 ):
# > 11335     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336     if isinstance(result, Series):
#   11337         result = result.__finalize__(self, method="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
# ...

# %%
df
# Out:
#                                                   title  \
# 0                           The Hunchback of Notre-Dame
# 1     La Cucina Di Lidia: Recipes and Memories from ...
# 2                                     Breach of Promise
# 3                     Brief Interviews with Hideous Men
# 4     The Killing Dance (Anita Blake  Vampire Hunter...
# ...                                                 ...
# 4995                                 The Complete Works
# 4996                               Shipwreck (Island I)
# 4997           Every Night Italian: Every Night Italian
# 4998                                     Go Down  Moses
# 4999  The Avignon Quintet: Monsieur  Livia  Constanc...
#
#                            author  average_rating         isbn13  \
# 0                     Victor Hugo            4.00  9780345472427
# 1     Lidia Matticchio Bastianich            4.14  9780767914222
# 2                James Scott Bell            4.00  9780310243878
# ...

# %%
high_rated_books = df[df['average_rating']>4]

# %%
high_rated_books
# Out:
#                                                   title  \
# 1     La Cucina Di Lidia: Recipes and Memories from ...
# 4     The Killing Dance (Anita Blake  Vampire Hunter...
# 5          The Hand of Chaos (The Death Gate Cycle  #5)
# 6                                       On Intelligence
# 11                        Merlin's Tour of the Universe
# ...                                                 ...
# 4991                                       'Salem's Lot
# 4992                  A Mad People's History of Madness
# 4993     A Christmas Carol (Great Illustrated Classics)
# 4995                                 The Complete Works
# 4999  The Avignon Quintet: Monsieur  Livia  Constanc...
#
#                            author  average_rating         isbn13  \
# 1     Lidia Matticchio Bastianich            4.14  9780767914222
# 4             Laurell K. Hamilton            4.13  9780425209066
# 5                   Margaret Weis            4.06  9780553563696
# ...

# %%
num_high_rated_books = len(high_rated_books)

# %%
print(f'the number of books with an average rating gretaer than 4 is:{num_high_rated_books}')
# Out:
# the number of books with an average rating gretaer than 4 is:2115

# %%
df[(df['average_rating']>4.5) & (df['ratings_count']<10)]
# Out:
#                                                   title  \
# 63                                             鋼之鍊金術師 9
# 178                                            鋼之鍊金術師 6
# 224                             Stargirl LitPlans on CD
# 454   Literature Circle Guide: Bridge to Terabithia:...
# 584                       Falling Angels (Luc Actar #1)
# 681        Fanning the Flame: Bible  Cross  and Mission
# 696                  Tyrannosaurus Wrecks (Stanley  #1)
# 741   The John Deere Two-Cylinder Tractor Encycloped...
# 757   The American Campaign: U.S. Presidential Campa...
# 1837  The Goon Show  Volume 4: My Knees Have Fallen ...
# 1856                                          鋼之鍊金術師 10
# 1960  Wissenschaft der Logik: Die Lehre Vom Begriff ...
# 2244  Getting a Grip on the Basics: Building a Firm ...
# 2496                               Come Away My Beloved
# 3178  Organizational Architecture: Designs for Chang...
# 3438         Bill Gates: Computer Legend (Famous Lives)
# ...

# %%
mean_ratings = df[df['language_code'] == 'eng'].groupby('language_code')['average_rating'].mean()
print(mean_ratings)
# Out:
# language_code
# eng    3.931143
# Name: average_rating, dtype: float64

# %%
df.iloc[0:5,0:4]
# Out:
#                                                title  \
# 0                        The Hunchback of Notre-Dame
# 1  La Cucina Di Lidia: Recipes and Memories from ...
# 2                                  Breach of Promise
# 3                  Brief Interviews with Hideous Men
# 4  The Killing Dance (Anita Blake  Vampire Hunter...
#
#                         author  average_rating         isbn13
# 0                  Victor Hugo            4.00  9780345472427
# 1  Lidia Matticchio Bastianich            4.14  9780767914222
# 2             James Scott Bell            4.00  9780310243878
# 3         David Foster Wallace            3.86  9780349111889
# 4          Laurell K. Hamilton            4.13  9780425209066

# %%
df.loc[[1,4],['language_code', 'num_pages', 'ratings_count']]
# Out:
#   language_code  num_pages  ratings_count
# 1         en-GB      288.0             48
# 4         en-US      368.0          59524

# %%
df['num_pages'].mean()
# Out:
# 341.0940205355345

# %%
df['num_pages'].median()
# Out:
# 304.0

# %%
df[df['year'] > 2009].shape[0]
# Out:
# 5000

# %%
df = pd.read_csv('books.csv')
df[df['year']==2010].shape[0]
# Out:
# 15

# %%
selected_books = df[(df['publisher'] == 'DAW') & (df['average_rating'] > 4)]

# %%
selected_books
# Out:
#                                                title           author  \
# 71                           By the Sword (Valdemar)  Mercedes Lackey
# 871         Storm Rising (Valdemar: Mage Storms  #2)  Mercedes Lackey
# 1523       Phoenix and Ashes (Elemental Masters  #3)  Mercedes Lackey
# 1583  To Battle the Gods (Jalav  Amazon Warrior  #5)     Sharon Green
# 3726        Oathblood (Valdemar: Vows and Honor  #3)  Mercedes Lackey
# 4367                     Joust (Dragon Jousters  #1)  Mercedes Lackey
#
#       average_rating         isbn13 language_code  num_pages  ratings_count  \
# 71              4.25  9780886774639           eng      492.0          18531
# 871             4.02  9780886777128         en-US      412.0          10781
# 1523            4.01  9780756402723           eng      480.0           6980
# 1583            4.07  9780886771287           eng      446.0             87
# 3726            4.06  9780886777739         en-GB      394.0           9786
# ...

# %%
selected_books['author'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0                Victor Hugo
# 12              Ray Bradbury
# 13       James H. Billington
# 16            John Steinbeck
# 17                Lyle Saxon
#                 ...
# 4963        Michael Connelly
# 4965    Doris Kearns Goodwin
# 4989           Peter Ackroyd
# 4995     Michel de Montaigne
# 4999        Lawrence Durrell
# Name: author, Length: 772, dtype: object>

# %% [markdown]
# How many books with more than 500 pages were published after 2010?

# %%
df = pd.read_csv('books.csv')
df[(df['num_pages'] > 500) & (df['year'] >2010)].shape[0]
# Out:
# 5

# %%
df[df['author'] == 'Agatha Christie'].shape[0]
# Out:
# 21

# %%
df[(df['language_code'] == 'spa') & (df['year'] > 2000)].shape[0]
# Out:
# 97

# %%
a = df[(df['average_rating']>4) &
       (df['publisher']=='DAW')] 
pd.unique(a['author'])
# Out:
# array(['Mercedes Lackey', 'Sharon Green'], dtype=object)

# %%
df = pd.read_csv('books.csv')

# %%
(df[(df['year']>2010) & 
    (df['num_pages']>500)]).shape[0]
# Out:
# 5

# %%
c = df[df['year']>2000 ]
c.groupby('language_code').count()
# Out:
#                title  author  average_rating  isbn13  num_pages  \
# language_code
# en-GB             70      70              70      70         69
# en-US            451     451             451     451        446
# eng             2476    2476            2476    2476       2456
# ger               28      28              28      28         28
# jpn               13      13              13      13         13
# lat                1       1               1       1          1
# mul                2       2               2       2          2
# spa               84      84              84      84         83
#
#                ratings_count  text_reviews_count  publisher  year
# language_code
# en-GB                     70                  70         70    70
# en-US                    451                 451        451   451
# eng                     2476                2476       2476  2476
# ger                       28                  28         28    28
# ...
