# %%
## Import libraries for data manipulation
import numpy as np
import pandas as pd
## Import libraries for data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats 
from scipy.stats import norm
from sklearn.impute import SimpleImputer
from statsmodels.formula.api import ols
from scipy.stats import ttest_1samp,ttest_ind
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
## For n-way ANOVA
from statsmodels.stats.anova import anova_lm

# %% [markdown]
# # Problem - 1

# %% [markdown]
# #### 1.1) What is the probability that a randomly chosen player would suffer an injury

# %%
## total Players injured - a = 145
## total Players(injured + not injured) - b = 235
a=145
b=235
## The Probability of a randomly chosen player would suffer injury = x
x=a/b
print('The probability of a randomly chosen player would suffer injury is =',x)
# Out:
# The probability of a randomly chosen player would suffer injury is = 0.6170212765957447

# %% [markdown]
# #### Ans: The probability of a randomly chosen player would suffer an injury is = 0.6170212765957447

# %% [markdown]
# #### 1.2) What is the probability that a player is a forward or a winger?

# %%
## total No of Forward players - a = 94
## total number of winger - b = 29
## total number of players - c = 235
a=94
b=29
c=235
## The probability that a player is a forward or a winger = x
x=(a+b)/c
print('The probability of a player is a forward or a winger =',x)
# Out:
# The probability of a player is a forward or a winger = 0.5234042553191489

# %% [markdown]
# #### Ans: The probability of a player is a forward or a winger = 0.5234042553191489

# %% [markdown]
# #### 1.3) What is the probability that a randomly chosen player plays in a striker position and has a foot injury?

# %%
## total number of strikers in the injured section - a = 45
## total Players - b = 235
a=45
b=235
## the probability of a randomly chosen player plays in a striker position and has a foot injury = x
x=a/b
print('The probability of a randomly chosen player plays in a striker position and has a foot injury =',x)
# Out:
# The probability of a randomly chosen player plays in a striker position and has a foot injury = 0.19148936170212766

# %% [markdown]
# #### Ans: The probability of a randomly chosen player plays in a striker position and has a foot injury = 0.19148936170212766

# %% [markdown]
# #### 1.4) What is the probability that a randomly chosen injured player is a striker?

# %%
## total number of strikers in the injured category - a = 45
## total Players of injured - b = 145
a=45
b=145
## the probability that a randomly chosen injured player is a striker = x
x=a/b
print('The probability of a randomly chosen injured player is a striker =',x)
# Out:
# The probability of a randomly chosen injured player is a striker = 0.3103448275862069

# %% [markdown]
# #### Ans: The probability of a randomly chosen injured player is a striker = 0.3103448275862069

# %% [markdown]
# #### 1.5) What is the probability that a randomly chosen injured player is either a forward or an attacking midfielder?

# %%
## total No of Forward players - a = 56
## total number of midfielder - b = 24
## total number of injured - c = 145
a=56
b=24
c=145
## the probability that a randomly chosen injured player is either a forward or an attacking midfielder = x
x=(a+b)/c
print('the probability that a randomly chosen injured player is either a forward or an attacking midfielder =',x)
# Out:
# the probability that a randomly chosen injured player is either a forward or an attacking midfielder = 0.5517241379310345

# %% [markdown]
# #### Ans: the probability that a randomly chosen injured player is either a forward or an attacking midfielder = 0.5517241379310345

# %% [markdown]
# # Problem - 2

# %%
## mean - mu = 5Kg/Sq.cm
## Sigma - sigma = 1.5Kg/Sq.cm
mu = 5
sigma = 1.5

# %% [markdown]
# #### 2.1) What proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm

# %%
## Gunny bags Strength < 3.17Kg/Sq.cm
## Z = (x-mu)/sigma
z=((3.17-5)/1.5)
z
# Out:
# -1.22

# %%
## norm.cdf() cumulative probability
stats.norm.cdf(-1.22)
# Out:
# 0.11123243744783456

# %%
## Creating an array of x value
x = np.linspace(-4, 4, 100)
pdf = norm.pdf(x, 0, 1)
plt.axvline(x=z,c='r')
## Define the region to fill
x_fill = np.linspace(-1.22, -4, 100)
y_fill = norm.pdf(x_fill, 0, 1)

## Plot the normal distribution
plt.plot(x, pdf, label="Normal Distribution")

## Filling the area between the curve
plt.fill_between(x_fill, y_fill, color="red", label="Area between -1.22 and -4")

## labels
plt.xlabel("Breaking Strength")
plt.ylabel("Probability")
plt.title("Normal Distribution")

## plot
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### As per the P-Value 11.12% proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm.

# %% [markdown]
# #### 2.2) What proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm.?

# %%
## mu = 5Kg/Sq.cm
## sigma = 1.5Kg/Sq.cm

Z=((3.6-5)/1.5)
Z
# Out:
# -0.9333333333333332

# %%
## norm.cdf() cumulative probability
1-stats.norm.cdf(-0.933)
# Out:
# 0.8245900158241952

# %%
x=np.linspace(-4,4,100)
plt.plot(x,norm.pdf(x,0,1))
plt.axvline(x=Z,c='r')

plt.fill_between(x, norm.pdf(x, 0, 1), where=(x >= -0.93333) & (x <= 4), color='red',label="Area between -0.9333 and 4")
## labels
plt.xlabel("Breaking Strength")
plt.ylabel("Probability")
plt.title("Normal Distribution")

## plot
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### As per the P-Value 82.45% of the gunny bags have a breaking strength of at least 3.6 kg per sq cm.

# %% [markdown]
# #### 2.3)What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?

# %%
## X = 5.5 
## mu = 5,  sigma = 1.5
## Z score = x - μ/ σ

z=(5.5 - 5)/ 1.5
z
# Out:
# 0.3333333333333333

# %%
## norm.cdf() cumulative probability
stats.norm.cdf(0.3333333333333333)-0.5
# Out:
# 0.13055865981823633

# %%
x1 = np.linspace(-4, 4 , 100)
plt.plot(x, norm.pdf(x, 0, 1))
plt.axvline(x=0 ,c="r")
plt.axvline(x=-0.9333 ,c="r")

plt.fill_between(x1, norm.pdf(x,0, 1), where=(x1 >= -0.9333) & (x1 <= 0), color="r",label="Area between -0.9333 and 0")
## labels
plt.xlabel("Breaking Strength")
plt.ylabel("Probability")
plt.title("Normal Distribution")

## plot
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### As per the P-Value 13.05% of gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.

# %% [markdown]
# #### 2.4) What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?

# %%
Z1=((3-5)/1.5)
Z1
# Out:
# -1.3333333333333333

# %%
Z2=((7.5-5)/1.5)
Z2
# Out:
# 1.6666666666666667

# %%
## using direct method
## find the cumulative probability
## norm.cdf()
Prob = stats.norm.cdf(3,loc=mu,scale=sigma) + 1 - stats.norm.cdf(7.5,loc=mu,scale=sigma)
Prob
# Out:
# 0.13900157199868257

# %%
plt.plot(x, norm.pdf(x, 0, 1))
plt.axvline(x=-1.333 ,c="r")
plt.axvline(x=1.666 ,c="r")
x1 = np.linspace(-4, 4, 100)
x2 = np.linspace(-4, 4, 100)

plt.fill_between(x1, norm.pdf(x1), where=(x1 >= -4) & (x1 <= -1.333), color="r",label="Area between -4 and -1.333")
plt.fill_between(x2, norm.pdf(x2), where=(x2 >= 1.58) & (x2 <= 4), color="r",label="Area between 1.666 and 4")

## labels
plt.xlabel("Breaking Strength")
plt.ylabel("Probability")
plt.title("Normal Distribution")

## plot
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### As per the P-Value 13.90% of proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.

# %% [markdown]
# # Problem - 3

# %%
#importing the dataset
df1=pd.read_csv('Downloads/Advance Statistics/Zingaro_Company.csv')

# %%
## Head of the dataset
df1.head()
# Out:
#    Unpolished   Treated and Polished
# 0   164.481713            133.209393
# 1   154.307045            138.482771
# 2   129.861048            159.665201
# 3   159.096184            145.663528
# 4   135.256748            136.789227

# %%
## Tail of the dataset
df1.tail()
# Out:
#     Unpolished   Treated and Polished
# 70   123.067611            142.293544
# 71   171.822218            140.124092
# 72    88.135994            141.393091
# 73   145.150397            131.370530
# 74   170.854823            144.502647

# %%
df1.info
# Out:
# <bound method DataFrame.info of     Unpolished   Treated and Polished
# 0    164.481713            133.209393
# 1    154.307045            138.482771
# 2    129.861048            159.665201
# 3    159.096184            145.663528
# 4    135.256748            136.789227
# ..          ...                   ...
# 70   123.067611            142.293544
# 71   171.822218            140.124092
# 72    88.135994            141.393091
# 73   145.150397            131.370530
# 74   170.854823            144.502647
#
# [75 rows x 2 columns]>

# %%
df1.shape
# Out:
# (75, 2)

# %%
df1.describe().T
# Out:
#                       count        mean        std         min         25%  \
# Unpolished             75.0  134.110527  33.041804   48.406838  115.329753
# Treated and Polished   75.0  147.788117  15.587355  107.524167  138.268300
#
#                              50%         75%         max
# Unpolished            135.597121  158.215098  200.161313
# Treated and Polished  145.721322  157.373318  192.272856

# %%
## checking null values
df1.isnull().sum()
# Out:
# Unpolished              0
# Treated and Polished    0
# dtype: int64

# %%
## making a variable for Mean & Std deviation of each type of stone
sigma_unpolished = df1['Unpolished '].std()
Mu_unpolished = df1['Unpolished '].mean()
Mu_unpolished, sigma_unpolished
# Out:
# (134.11052653373332, 33.0418044136061)

# %%
sigma_polished = df1['Treated and Polished'].std()
Mu_polished = df1['Treated and Polished'].mean()
Mu_polished , sigma_polished
# Out:
# (147.78811718133335, 15.587355273119856)

# %% [markdown]
# #### 3.1)Zingaro has reason to believe that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?

# %%
mu = 150
sigma = 0.5
## H0(null hypothessis): Unpolished stones are suitable for printing
## Ha(alternative hypothesis): Unpolished stones are not suitable for printing.

# %% [markdown]
# H0(unpolised) >= 150
#
# HA(unpolised) < 150

# %%
t_statistic, p_value = ttest_1samp(df1['Unpolished '], 150)
print('One sample t test \nt statistic: {0} p value: {1} '.format(t_statistic, p_value))
# Out:
# One sample t test
# t statistic: -4.164629601426757 p value: 8.342573994839304e-05

# %%
print ("one sample t-test p-value=", p_value/2)
alpha_level = 0.05
if (p_value/2) < alpha_level:
    print('We have enough evidence to reject the null hypothesis in favour of the alternative hypothesis')
    
else:
    print('We do not have enough evidence to reject the null hypothesis in favour of the alternative hypothesis')
# Out:
# one sample t-test p-value= 4.171286997419652e-05
# We have enough evidence to reject the null hypothesis in favour of the alternative hypothesis

# %% [markdown]
# #### 3.2)Is the mean hardness of the polished and unpolished stones the same?

# %%
Unpolished =df1['Unpolished '].mean()
Polished = df1['Treated and Polished'].mean()
print('The mean of Unpolished and Polished stone:',Unpolished,Polished)
# Out:
# The mean of Unpolished and Polished stone: 134.11052653373332 147.78811718133335

# %%
t_statistic,p_value = ttest_ind(df1['Unpolished '],df1['Treated and Polished'])
print('t_statistic',t_statistic)
print('p_value',p_value)
# Out:
# t_statistic -3.2422320501414053
# p_value 0.0014655150194628353

# %% [markdown]
# We have enough evidence to reject the null hypothesis in favour of the alternative hypothesis

# %% [markdown]
# # Problem - 4

# %%
## Importing the dataset
dental = pd.read_excel('Downloads/Advance Statistics/Dental+Hardness+data.xlsx',sheet_name='Data')

# %%
## Checking the head & tail of data
dental.head()
# Out:
#    Dentist  Method  Alloy  Temp  Response
# 0        1       1      1  1500       813
# 1        1       1      1  1600       792
# 2        1       1      1  1700       792
# 3        1       1      2  1500       907
# 4        1       1      2  1600       792

# %%
dental.tail()
# Out:
#     Dentist  Method  Alloy  Temp  Response
# 85        5       3      1  1600       483
# 86        5       3      1  1700       405
# 87        5       3      2  1500       536
# 88        5       3      2  1600       405
# 89        5       3      2  1700       312

# %%
dental.shape
# Out:
# (90, 5)

# %%
dental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     int64
#  1   Method    90 non-null     int64
#  2   Alloy     90 non-null     int64
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: int64(5)
# memory usage: 3.6 KB

# %%
## Checking Null values
dental.isnull().sum()
# Out:
# Dentist     0
# Method      0
# Alloy       0
# Temp        0
# Response    0
# dtype: int64

# %%
dental.describe().T
# Out:
#           count         mean         std     min     25%     50%     75%  \
# Dentist    90.0     3.000000    1.422136     1.0     2.0     3.0     4.0
# Method     90.0     2.000000    0.821071     1.0     1.0     2.0     3.0
# Alloy      90.0     1.500000    0.502801     1.0     1.0     1.5     2.0
# Temp       90.0  1600.000000   82.107083  1500.0  1500.0  1600.0  1700.0
# Response   90.0   741.777778  145.767845   289.0   698.0   767.0   824.0
#
#              max
# Dentist      5.0
# Method       3.0
# Alloy        2.0
# Temp      1700.0
# Response  1115.0

# %% [markdown]
# #### Test for Normality - ShapiroWilk-Test

# %% [markdown]
# Ho: Population from which sample is drawn is normally distributed
#
# Ha : Population from which sample is drawn is not normally distributed

# %%
dental['Dentist'] = pd.Categorical(dental['Dentist'])
dental['Method'] = pd.Categorical(dental['Method'])
dental['Alloy'] = pd.Categorical(dental['Alloy'])

# %%
##importing shapiro
from scipy.stats import shapiro

## Applying Shapiro test on Dentist 
Dentist1 = dental[dental['Dentist'] == 1]['Response']
Dentist2 = dental[dental['Dentist'] == 2]['Response']
Dentist3 = dental[dental['Dentist'] == 3]['Response']
Dentist4 = dental[dental['Dentist'] == 4]['Response']
Dentist5 = dental[dental['Dentist'] == 5]['Response']
print(stats.shapiro(Dentist1))
print(stats.shapiro(Dentist2))
print(stats.shapiro(Dentist3))
print(stats.shapiro(Dentist4))
print(stats.shapiro(Dentist5))
# Out:
# ShapiroResult(statistic=0.9288938045501709, pvalue=0.1856756955385208)
# ShapiroResult(statistic=0.9665580987930298, pvalue=0.7310513854026794)
# ShapiroResult(statistic=0.9573881030082703, pvalue=0.5520960092544556)
# ShapiroResult(statistic=0.8089418411254883, pvalue=0.002037237398326397)
# ShapiroResult(statistic=0.9546374082565308, pvalue=0.5022943019866943)

# %% [markdown]
# #### As we can see sample for Dentist = 4 seems to be drawn from a population which is not normally distributed   p - value < 0.05

# %% [markdown]
# ##### We failed in shapiro - wilk test,So we conduct Anderson Darling Test

# %%
from scipy.stats import anderson

## Applying anderson test on Dentist 
print(stats.anderson(Dentist1, dist = 'norm'))
print(stats.anderson(Dentist2, dist = 'norm'))
print(stats.anderson(Dentist3, dist = 'norm'))
print(stats.anderson(Dentist4, dist = 'norm'))
print(stats.anderson(Dentist5, dist = 'norm'))
# Out:
# AndersonResult(statistic=0.5572318170702566, critical_values=array([0.503, 0.573, 0.687, 0.802, 0.954]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=783.0555555555555, scale=129.28148596910188)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
# AndersonResult(statistic=0.18489207423293408, critical_values=array([0.503, 0.573, 0.687, 0.802, 0.954]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=786.6666666666666, scale=77.43156371159974)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
# AndersonResult(statistic=0.31139490001785575, critical_values=array([0.503, 0.573, 0.687, 0.802, 0.954]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=748.6111111111111, scale=69.72562942485933)
#  success: True
# ...

# %% [markdown]
# #### Now, alpha = 0.05, critical value = 0.687, test statistic for Dentist 4 is > CV of alpha.

# %%
mc=MultiComparison(dental['Response'],dental['Dentist'] )
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2    3.6111    1.0 -129.0594 136.2816  False
#      1      3  -34.4444 0.9505 -167.1149   98.226  False
#      1      4  -69.3889 0.5925 -202.0594  63.2816  False
#      1      5 -106.1667 0.1786 -238.8371  26.5038  False
#      2      3  -38.0556 0.9301  -170.726  94.6149  False
#      2      4     -73.0 0.5438 -205.6705  59.6705  False
#      2      5 -109.7778  0.153 -242.4483  22.8927  False
#      3      4  -34.9444 0.9479 -167.6149   97.726  False
#      3      5  -71.7222  0.561 -204.3927  60.9483  False
#      4      5  -36.7778 0.9378 -169.4483  95.8927  False
# --------------------------------------------------------

# %%
## Distribution Plot of Dentist
plt.figure(figsize =[20,10])
plt.suptitle('Histograms')
plt.subplot(2,3,1)
plt.title('Dentist1')
sns.histplot(Dentist1, kde = 'True');
plt.subplot(2,3,2)
plt.title('Dentist2')
sns.histplot(Dentist2, kde = 'True');
plt.subplot(2,3,3)
plt.title('Dentist3')
sns.histplot(Dentist3, kde = 'True');
plt.subplot(2,3,4)
plt.title('Dentist4')
sns.histplot(Dentist4, kde = 'True');
plt.subplot(2,3,5)
plt.title('Dentist5')
sns.histplot(Dentist5, kde = 'True');

# %%
plt.figure(figsize=(20, 10))
plt.suptitle('Box Plots')

## box plots
plt.subplot(2, 3, 1)
plt.title('Dentist1')
sns.boxplot(data=Dentist1)
plt.subplot(2, 3, 2)
plt.title('Dentist2')
sns.boxplot(data=Dentist2)
plt.subplot(2, 3, 3)
plt.title('Dentist3')
sns.boxplot(data=Dentist3)
plt.subplot(2, 3, 4)
plt.title('Dentist4')
sns.boxplot(data=Dentist4)
plt.subplot(2, 3, 5)
plt.title('Dentist5')
sns.boxplot(data=Dentist5)

plt.show()

# %%
## Applying Shapiro test on  Method
Method1 = dental[dental['Method'] == 1]['Response']
Method2 = dental[dental['Method'] == 2]['Response']
Method3 = dental[dental['Method'] == 3]['Response']
print(stats.shapiro(Method1))
print(stats.shapiro(Method2))
print(stats.shapiro(Method3))
# Out:
# ShapiroResult(statistic=0.9652422666549683, pvalue=0.41838711500167847)
# ShapiroResult(statistic=0.9371030926704407, pvalue=0.07601878046989441)
# ShapiroResult(statistic=0.9091948866844177, pvalue=0.014201466925442219)

# %% [markdown]
# #### As the Shapiro wilks Test Fails for Method 3 Sample   p - value < 0.05

# %%
## Applying anderson test on Method 
print(stats.anderson(Method1, dist = 'norm'))
print(stats.anderson(Method2, dist = 'norm'))
print(stats.anderson(Method3, dist = 'norm'))
# Out:
# AndersonResult(statistic=0.3135591167842904, critical_values=array([0.521, 0.593, 0.712, 0.83 , 0.988]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=793.9, scale=86.4727782559942)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
# AndersonResult(statistic=0.5334878167302541, critical_values=array([0.521, 0.593, 0.712, 0.83 , 0.988]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=804.3333333333334, scale=95.77103922388537)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
# AndersonResult(statistic=0.9931748727975247, critical_values=array([0.521, 0.593, 0.712, 0.83 , 0.988]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=627.1, scale=167.62321253129096)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
## Create a 2x3 grid for subplots
plt.figure(figsize=(20, 10))
plt.suptitle('Distribution Plots and Box Plots')

## Distribution plots (histograms)
for i, method in enumerate([Method1, Method2, Method3], start=1):
    plt.subplot(2, 3, i)
    plt.title(f'Method{i}')
    sns.histplot(method, kde=True)

## Box plots
for i, method in enumerate([Method1, Method2, Method3], start=4):
    plt.subplot(2, 3, i)
    plt.title(f'Method{i-3}')
    sns.boxplot(data=method)

plt.show()

# %% [markdown]
# #### 4.1 How does the hardness of implants vary depending on dentists?

# %%
## Creating two seperate sets for each Alloy
dental1 = dental[dental['Alloy'] == 1]
dental2 = dental[dental['Alloy'] == 2]

# %% [markdown]
# #### The Hypothesis for the One Way ANOVA are:
# H0: There is ependencee among Dentists on implant hardness
#
# Ha: There is nependencence among Dentists on implant hardness

# %%
## For the Alloy 1
formula = 'Response ~ C(Dentist)'
model = ols(formula, dental1).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  1.977112  0.116567
# Residual    40.0  539593.555556  13489.838889       NaN       NaN

# %%
## For Alloy 2
formula = 'Response ~ C(Dentist)' 
model = ols(formula, dental2).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  5.679791e+04  14199.477778  0.524835  0.718031
# Residual    40.0  1.082205e+06  27055.122222       NaN       NaN

# %%
mc=MultiComparison(dental1['Response'],dental1['Dentist'] )
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   11.3333 0.9996 -145.0423  167.709  False
#      1      3  -32.3333 0.9757  -188.709 124.0423  False
#      1      4  -68.7778 0.7189 -225.1535  87.5979  False
#      1      5 -122.2222 0.1889 -278.5979  34.1535  False
#      2      3  -43.6667 0.9298 -200.0423  112.709  False
#      2      4  -80.1111 0.5916 -236.4868  76.2646  False
#      2      5 -133.5556 0.1258 -289.9312  22.8201  False
#      3      4  -36.4444 0.9626 -192.8201 119.9312  False
#      3      5  -89.8889 0.4805 -246.2646  66.4868  False
#      4      5  -53.4444 0.8643 -209.8201 102.9312  False
# --------------------------------------------------------

# %%
mc=MultiComparison(dental2['Response'],dental2['Dentist'] )
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      1      2  -4.1111    1.0 -225.5687 217.3465  False
#      1      3 -36.5556 0.9895 -258.0131  184.902  False
#      1      4    -70.0 0.8941 -291.4576 151.4576  False
#      1      5 -90.1111 0.7724 -311.5687 131.3465  False
#      2      3 -32.4444 0.9933  -253.902 189.0131  False
#      2      4 -65.8889 0.9132 -287.3465 155.5687  False
#      2      5    -86.0 0.8008 -307.4576 135.4576  False
#      3      4 -33.4444 0.9925  -254.902 188.0131  False
#      3      5 -53.5556 0.9574 -275.0131  167.902  False
#      4      5 -20.1111  0.999 -241.5687 201.3465  False
# -------------------------------------------------------

# %% [markdown]
# at p - value > 0.05 Fail to Reject H0
#
#  At 95 % confidence we have on statistical evidence to state that the Dentists has no effect on implant hardness.

# %%
anderson(dental1['Response'],dist='norm')
# Out:
# AndersonResult(statistic=2.561066309273201, critical_values=array([0.535, 0.609, 0.731, 0.853, 1.014]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=707.4888888888889, scale=121.1945509992887)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
anderson(dental2['Response'],dist='norm')
# Out:
# AndersonResult(statistic=1.8931311726356412, critical_values=array([0.535, 0.609, 0.731, 0.853, 1.014]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=776.0666666666667, scale=160.89259545649472)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
plt.ylim(dental1['Response'].min(), dental1['Response'].max())
sns.pointplot(y = 'Response', x = 'Dentist', data = dental1, hue = 'Alloy', ci = None);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16896\840588556.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(y = 'Response', x = 'Dentist', data = dental1, hue = 'Alloy', ci = None);

# %%
plt.ylim(dental2['Response'].min(), dental2['Response'].max())
sns.pointplot(y = 'Response', x = 'Dentist', data = dental2,hue = 'Alloy', ci = None);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16896\1255861668.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(y = 'Response', x = 'Dentist', data = dental2,hue = 'Alloy', ci = None);

# %%
# Combine data for both alloys
combined_dental = pd.concat([dental1, dental2])

# Create a point plot with Alloy as hue
plt.figure(figsize=(10, 6))
sns.pointplot(y='Response', x='Dentist', hue='Alloy', data=combined_dental, ci=None)
plt.title("Implant Hardness by Dentist (Alloy 1 vs. Alloy 2)")
plt.xlabel("Dentist")
plt.ylabel("Implant Hardness")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16896\786155014.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(y='Response', x='Dentist', hue='Alloy', data=combined_dental, ci=None)

# %% [markdown]
# #### 4.2 How does the hardness of implants vary depending on methods?

# %% [markdown]
# Performing One Way ANOVA with the variable 'Method' with respect to 'Response'
#
# The Hypothesis for the One Way ANOVA are:
#
# H0: There is dependence among Method on implant hardness
#
# Ha: There is no dependence among Method on implant hardness

# %%
formula = 'Response ~ C(Method)'
model = ols(formula, dental1).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#              df         sum_sq       mean_sq         F    PR(>F)
# C(Method)   2.0  148472.177778  74236.088889  6.263327  0.004163
# Residual   42.0  497805.066667  11852.501587       NaN       NaN

# %%
formula = 'Response ~ C(Method)'
model = ols(formula, dental2).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#              df    sum_sq        mean_sq        F    PR(>F)
# C(Method)   2.0  499640.4  249820.200000  16.4108  0.000005
# Residual   42.0  639362.4   15222.914286      NaN       NaN

# %%
mc=MultiComparison(dental1['Response'],dental1['Method'])
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %%
mc=MultiComparison(dental2['Response'],dental2['Method'])
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %%
# Combine data for both alloys
combined_dental = pd.concat([dental1, dental2])

# Create a point plot with Alloy as hue
plt.figure(figsize=(10, 6))
sns.pointplot(y='Response', x='Method', hue='Alloy', data=combined_dental, ci=None)
plt.title("Implant Hardness by method (Alloy 1 vs. Alloy 2)")
plt.xlabel("Method")
plt.ylabel("Implant Hardness")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16896\1756015684.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(y='Response', x='Method', hue='Alloy', data=combined_dental, ci=None)

# %%
sns.pointplot(x='Method', y='Response', data=dental, hue='Dentist',  markers = ['o', 'd', '^','D','>'] ,ci=None,ms = 6);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16896\2674312670.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Method', y='Response', data=dental, hue='Dentist',  markers = ['o', 'd', '^','D','>'] ,ci=None,ms = 6);

# %% [markdown]
# #### 4.3 What is the interaction effect between the dentist and method on the hardness of dental implants for each type of alloy?

# %%
formula = 'Response ~ C(Method) + C(Dentist)'
model = ols(formula, dental1).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Method)    2.0  148472.177778  74236.088889  7.212522  0.002211
# C(Dentist)   4.0  106683.688889  26670.922222  2.591255  0.051875
# Residual    38.0  391121.377778  10292.667836       NaN       NaN

# %%
formula = 'Response ~ C(Method) + C(Dentist)'
model = ols(formula, dental2).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#               df         sum_sq        mean_sq          F    PR(>F)
# C(Method)    2.0  499640.400000  249820.200000  16.295479  0.000008
# C(Dentist)   4.0   56797.911111   14199.477778   0.926215  0.458933
# Residual    38.0  582564.488889   15330.644444        NaN       NaN

# %%
formula = 'Response ~ C(Method) + C(Dentist)+C(Temp)'
model = ols(formula, dental1).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Method)    2.0  148472.177778  74236.088889  7.015042  0.002675
# C(Dentist)   4.0  106683.688889  26670.922222  2.520306  0.058017
# C(Temp)      2.0   10154.444444   5077.222222  0.479779  0.622821
# Residual    36.0  380966.933333  10582.414815       NaN       NaN

# %%
formula = 'Response ~ C(Method) + C(Dentist)+C(Temp)'
model = ols(formula, dental2).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#               df         sum_sq        mean_sq          F    PR(>F)
# C(Method)    2.0  499640.400000  249820.200000  18.398611  0.000003
# C(Dentist)   4.0   56797.911111   14199.477778   1.045755  0.397313
# C(Temp)      2.0   93748.933333   46874.466667   3.452183  0.042503
# Residual    36.0  488815.555556   13578.209877        NaN       NaN

# %%
formula = 'Response ~ C(Method) + C(Dentist) + C(Method):C(Dentist)'
model = ols(formula, dental1).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#                         df         sum_sq       mean_sq          F    PR(>F)
# C(Method)              2.0  148472.177778  74236.088889  10.854287  0.000284
# C(Dentist)             4.0  106683.688889  26670.922222   3.899638  0.011484
# C(Method):C(Dentist)   8.0  185941.377778  23242.672222   3.398383  0.006793
# Residual              30.0  205180.000000   6839.333333        NaN       NaN

# %%
formula = 'Response ~ C(Method) + C(Dentist) + C(Method):C(Dentist)'
model = ols(formula, dental2).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#                         df         sum_sq        mean_sq          F    PR(>F)
# C(Method)              2.0  499640.400000  249820.200000  19.461218  0.000004
# C(Dentist)             4.0   56797.911111   14199.477778   1.106152  0.371833
# C(Method):C(Dentist)   8.0  197459.822222   24682.477778   1.922787  0.093234
# Residual              30.0  385104.666667   12836.822222        NaN       NaN

# %%
from statsmodels.graphics.factorplots import interaction_plot
# Combine data for both alloys
combined_dental = pd.concat([dental1, dental2])
fig, ax = plt.subplots(figsize = [15,8])
fig = interaction_plot(np.array(combined_dental['Dentist']), np.array(combined_dental['Method']), np.array(combined_dental['Response']), markers = ['o', 'd', '^'], 
                       colors = ['orange', 'purple', 'green'], ax = ax, xlabel = 'Dentist', ylabel = 'Response', ms = 6);
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\statsmodels\graphics\factorplots.py:113: FutureWarning: The provided callable <function mean at 0x0000021677DF1EE0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   plot_data = data.groupby(['trace', 'x']).aggregate(func).reset_index()

# %%
sns.pointplot(x='Dentist', y='Response', data=dental1, hue='Method',markers = ['o', 'd', '^'], ms = 6 ,errorbar=None);

# %%
sns.pointplot(x='Dentist', y='Response', data=dental2, hue='Method',markers = ['o', 'd', '^'], ms = 6 ,errorbar=None);

# %%
sns.pointplot(x='Dentist', y='Response', data=combined_dental, hue='Method',markers = ['o', 'd', '^'], ms = 6 ,errorbar=None);

# %% [markdown]
# #### 4.4) How does the hardness of implants vary depending on dentists and methods together?

# %%
formula = 'Temp ~ C(Method) + C(Dentist) + C(Method):C(Dentist)'
model = ols(formula, dental1).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#                         df        sum_sq       mean_sq             F  PR(>F)
# C(Method)              2.0  3.166551e-25  1.583275e-25  1.583275e-29     1.0
# C(Dentist)             4.0  2.536472e-24  6.341180e-25  6.341180e-29     1.0
# C(Method):C(Dentist)   8.0  6.311291e-24  7.889114e-25  7.889114e-29     1.0
# Residual              30.0  3.000000e+05  1.000000e+04           NaN     NaN

# %%
formula = 'Temp ~ C(Method) + C(Dentist) + C(Method):C(Dentist)'
model = ols(formula, dental2).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#                         df        sum_sq       mean_sq             F  PR(>F)
# C(Method)              2.0  3.166551e-25  1.583275e-25  1.583275e-29     1.0
# C(Dentist)             4.0  2.536472e-24  6.341180e-25  6.341180e-29     1.0
# C(Method):C(Dentist)   8.0  6.311291e-24  7.889114e-25  7.889114e-29     1.0
# Residual              30.0  3.000000e+05  1.000000e+04           NaN     NaN

# %%
formula = 'Response ~ C(Temp)'
model = ols(formula, dental1).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#             df         sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0   10154.444444   5077.222222  0.335224  0.717074
# Residual  42.0  636122.800000  15145.780952       NaN       NaN

# %%
formula = 'Response ~ C(Temp)'
model = ols(formula, dental2).fit()
anova_table = anova_lm(model)
print(anova_table)
# Out:
#             df        sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0  9.374893e+04  46874.466667  1.883492  0.164678
# Residual  42.0  1.045254e+06  24886.996825       NaN       NaN

# %%
sns.pointplot(x='Temp', y='Response', data=dental, hue='Alloy',ci=None);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16896\283029833.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Temp', y='Response', data=dental, hue='Alloy',ci=None);

# %% [markdown]
# #                                                                        END
